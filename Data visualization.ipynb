# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x=np.linspace(0,10)
plt.plot(x,np.sin(x),color='pink')

# %%
plt.plot(x,np.sin(x),color='pink')

# %%
plt.plot(x,np.sin(x),linestyle='solid')

# %%
plt.plot(x,np.sin(x),linestyle='dashed')

# %%
plt.plot(x,np.sin(x),linestyle='dashdot')

# %%
plt.plot(x,np.sin(x),linestyle='dotted')

# %%
plt.plot(x,np.cos(x),'ys')
plt.show()

# %%
plt.plot(x,np.cos(x),'yd')
plt.show()

# %%
plt.plot(x,np.cos(x),'yo')
plt.show()

# %%
plt.plot(x,np.cos(x),'y>')
plt.show()

# %%
plt.plot(x,np.cos(x),'y<')
plt.show()

# %%
plt.plot(x,np.cos(x),'y1')
plt.show()

# %%
plt.plot(x,np.cos(x),'y2')
plt.show()

# %%
plt.plot(x,np.cos(x),'y3')
plt.show()

# %%
plt.plot(x,np.cos(x),'yh')
plt.show()

# %%
plt.plot([1,2,3])
plt.show()

# %%
guests=[19,22,20,26]
subscribers=[105,103,98,83]
plt.plot([guests,subscribers])

# %%
langs =['c','c++','java','python','php']
students=[23,17,35,29,12]
plt.bar(langs,students,width=0.75,color='green')
# Out:
# <BarContainer object of 5 artists>

# %%
langs =['c','c++','java','python','php']
students=[23,17,35,29,12]
plt.barh(langs,students,color='violet')
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#  np.random.seed(10)
collectn_1=np.random.normal(100,10,200)
collectn_2=np.random.normal(80,20,200)
collectn_3=np.random.normal(90,50,200)
collectn_4=np.random.normal(70,40,200)
data=[collectn_1,collectn_2,collectn_3,collectn_4]
bp=plt.boxplot(data)
plt.show()

# %%
x=[1,2,3,4,5,6,7,8]
y=[5,2,4,2,1,4,5,2]
plt.scatter(x,y,color='black',marker='D',label='Graph')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Graph between X-Y')
plt.legend(loc='upper right')
